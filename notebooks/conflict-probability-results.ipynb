# %% [markdown]
# # Conflict Probability Results
#
# These results plot our simulation metrics against increasing conflict probability.
#
# ## Multiple Results Analysis
#
# This notebook is intended to read a simulation results file with multiple simulations and results and create aggregate analyses and visualizations.
#
# **Goal**:
#
# 1. Raft doesn't commit forks
# 2. Raft accepts first seen
# 3. Eventual chooses raft then latest
#
# **Experimental control variables:**
#
# - _increasing WAN latency, e.g. T (tick)_
# - increasing number of nodes
# - increasing amounts of failure
#
# **Metrics:**
#
# - number of forks
# - number of stale reads
# - percent visible (for full replication)
# - percent committed
# - number of messages
# - read latency
# - write latency
# - visibility latency
# - commit latency

# %%
# %load_ext memory_profiler
# %matplotlib inline

import os
import sys 
import json
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import graph_tool.all as gt
import matplotlib.pyplot as plt

from operator import itemgetter
from itertools import groupby, chain
from collections import defaultdict, Counter

# Modify the Notebook path
sys.path.append(os.path.join(os.getcwd(), ".."))

from cloudscope.colors import ColorMap
from cloudscope.results import Results
from cloudscope.results.graph import extract_graph
from cloudscope.results.analysis import create_per_replica_dataframe as create_replica_dataframe
from cloudscope.results.analysis import create_per_experiment_dataframe as create_dataframe

# %%
sns.set_style('whitegrid')
sns.set_context('talk')
sns.set_palette('Set1')

# %%
# Specify a path to a results file 
# If None, will attempt to look one up
FIXTURES = os.path.join("..", "fixtures", "results")
FIGURES  = os.path.join("..", "fixtures", "figures")
RESULTS  = os.path.join(FIXTURES, "conflict-experiment.json")
RESULTS  = os.path.join(FIXTURES, "stentor-conflict.json")

def get_results_data(path=RESULTS):
    with open(path, 'r') as f:
        for line in f:
            result = json.loads(line)
            yield Results(**result)

# %%
# %%memit
# df = create_dataframe(get_results_data())
# Out:
# peak memory: 2401.97 MiB, increment: 2276.42 MiB

# %%
# Uncomment below if you need to see the columns
# print("\n".join(df.columns))

# Add the ename to identify the experiment
df['ename'] = "Pc = " + df['conflict probability'].apply(str) + " " + df['T parameter model']
df['type']  = df['type'].apply(lambda s: s.title())

# %%
df
# Out:
#    T parameter model  anti-entropy delay (ms)  committed writes  \
# 0             bailis                      250               0.0
# 1             bailis                      250               0.0
# 2             bailis                      250               0.0
# 3             bailis                      250               0.0
# 4             bailis                      250               0.0
# 5             bailis                      250               0.0
# 6             bailis                      250               0.0
# 7             bailis                      250               0.0
# 8             bailis                      250               0.0
# 9             bailis                      250               0.0
# 10            bailis                      250               0.0
# 11            bailis                      250           18839.0
# 12            bailis                      250           19037.0
# 13            bailis                      250           18724.0
# 14            bailis                      250           19311.0
# 15            bailis                      250           20055.0
# 16            bailis                      250           18581.0
# 17            bailis                      250           19962.0
# 18            bailis                      250           19899.0
# 19            bailis                      250           19791.0
# 20            bailis                      250           19719.0
# 21            bailis                      250           19633.0
# 22            bailis                      250           19467.0
# 23            bailis                      250           19344.0
# 24            bailis                      250           19190.0
# 25            bailis                      250           19164.0
# 26            bailis                      250           18999.0
# 27            bailis                      250               0.0
# 28            bailis                      250               0.0
# 29            bailis                      250           18342.0
# 30            bailis                      250               0.0
# 31            bailis                      250               0.0
# 32            bailis                      250               0.0
# 33            bailis                      250               0.0
# 34            bailis                      250               0.0
# 35            bailis                      250               0.0
# 36            bailis                      250               0.0
# 37            bailis                      250               0.0
# 38            bailis                      250               0.0
# 39            bailis                      250               0.0
# 40            bailis                      250               0.0
# 41            bailis                      250               0.0
# 42            bailis                      250               0.0
# 43            bailis                      250               0.0
# 44            bailis                      250               0.0
# 45            bailis                      250               0.0
# 46            bailis                      250               0.0
# 47            bailis                      250               0.0
# 48            bailis                      250               0.0
# 49            bailis                      250               0.0
# 50            bailis                      250           19447.0
# 51            bailis                      250           19601.0
# 52            bailis                      250           19769.0
# 53            bailis                      250           19924.0
#
#     completed reads  completed writes  conflict probability  dropped writes  \
# 0             27812             20118                   0.7             0.0
# 1             27783             20119                   0.6             0.0
# 2             27792             20119                   0.5             0.0
# 3             27755             20118                   0.4             0.0
# 4             27722             20111                   0.3             0.0
# 5             27666             20101                   0.2             0.0
# 6             27528             20069                   0.1             0.0
# 7             27124             20055                   0.0             0.0
# 8             27827             20121                   0.8             0.0
# 9             27879             20123                   0.9             0.0
# 10            27845             20124                   1.0             0.0
# 11            27826             30898                   0.7          1273.0
# 12            27811             31138                   0.6          1070.0
# 13            27855             30820                   0.8          1390.0
# 14            27813             31397                   0.5           803.0
# 15            27123             20055                   0.0             0.0
# 16            27884             30675                   0.9          1538.0
# 17            27547             19962                   0.1           107.0
# 18            27706             19900                   0.2           201.0
# 19            27738             19792                   0.3           319.0
# 20            27798             19719                   0.4           399.0
# 21            27813             19633                   0.5           486.0
# 22            27811             19468                   0.6           651.0
# 23            27806             19344                   0.7           774.0
# 24            27835             19190                   0.8           931.0
# 25            27869             19164                   0.9           959.0
# 26            27852             18999                   1.0          1125.0
# 27            27124             20055                   0.0             0.0
# 28            27385             20069                   0.1             0.0
# 29            27865             30431                   1.0          1785.0
# 30            27568             20101                   0.2             0.0
# 31            27592             20111                   0.3             0.0
# 32            27659             20118                   0.4             0.0
# 33            27685             20119                   0.5             0.0
# 34            27709             20119                   0.6             0.0
# 35            27766             20118                   0.7             0.0
# 36            27774             20121                   0.8             0.0
# 37            27818             20123                   0.9             0.0
# 38            27812             20124                   1.0             0.0
# 39            27725             20101                   0.2             0.0
# 40            27555             20069                   0.1             0.0
# 41            27124             20055                   0.0             0.0
# 42            27757             20111                   0.3             0.0
# 43            27798             20118                   0.4             0.0
# 44            27813             20119                   0.5             0.0
# 45            27810             20119                   0.6             0.0
# 46            27823             20118                   0.7             0.0
# 47            27857             20121                   0.8             0.0
# 48            27884             20123                   0.9             0.0
# 49            27865             20124                   1.0             0.0
# 50            27796             31499                   0.4           667.0
# 51            27755             31729                   0.3           507.0
# 52            27724             31790                   0.2           331.0
# 53            27555             32005                   0.1           158.0
#
#     eid election timeout (ms, ms)  empty reads       ...         stale reads  \
# 0   e00              [1000, 2000]          107       ...              6714.0
# 1   e01              [1000, 2000]          131       ...              6181.0
# 2   e02              [1000, 2000]          120       ...              5227.0
# 3   e03              [1000, 2000]          154       ...              4784.0
# 4   e04              [1000, 2000]          193       ...              4332.0
# 5   e05              [1000, 2000]          255       ...              3464.0
# 6   e06              [1000, 2000]          424       ...              2187.0
# 7   e07              [1000, 2000]          842       ...                 0.0
# 8   e08              [1000, 2000]           87       ...              7351.0
# 9   e09              [1000, 2000]           32       ...              7663.0
# 10  e10              [1000, 2000]           69       ...              8346.0
# 11  e11              [1000, 2000]           93       ...              3622.0
# 12  e12              [1000, 2000]          103       ...              3139.0
# 13  e13              [1000, 2000]           59       ...              4027.0
# 14  e14              [1000, 2000]           99       ...              2249.0
# 15  e15              [1000, 2000]          843       ...                12.0
# 16  e16              [1000, 2000]           27       ...              4522.0
# 17  e17              [1000, 2000]          405       ...               475.0
# 18  e18              [1000, 2000]          215       ...               870.0
# 19  e19              [1000, 2000]          177       ...              1288.0
# 20  e20              [1000, 2000]          111       ...              1734.0
# 21  e21              [1000, 2000]           99       ...              2013.0
# 22  e22              [1000, 2000]          103       ...              2819.0
# 23  e23              [1000, 2000]          113       ...              3335.0
# 24  e24              [1000, 2000]           79       ...              3773.0
# 25  e25              [1000, 2000]           42       ...              4133.0
# 26  e26              [1000, 2000]           62       ...              4629.0
# 27  e27              [1000, 2000]          842       ...                 0.0
# 28  e28              [1000, 2000]          567       ...              1554.0
# 29  e29              [1000, 2000]           49       ...              5141.0
# 30  e30              [1000, 2000]          353       ...              2355.0
# 31  e31              [1000, 2000]          323       ...              3051.0
# 32  e32              [1000, 2000]          250       ...              3288.0
# 33  e33              [1000, 2000]          227       ...              3757.0
# 34  e34              [1000, 2000]          205       ...              4458.0
# 35  e35              [1000, 2000]          153       ...              5018.0
# 36  e36              [1000, 2000]          140       ...              5060.0
# 37  e37              [1000, 2000]           93       ...              5325.0
# 38  e38              [1000, 2000]          102       ...              6062.0
# 39  e39              [1000, 2000]          196       ...               556.0
# 40  e40              [1000, 2000]          397       ...               312.0
# 41  e41              [1000, 2000]          842       ...                 0.0
# 42  e42              [1000, 2000]          158       ...               796.0
# 43  e43              [1000, 2000]          111       ...               999.0
# 44  e44              [1000, 2000]           99       ...              1197.0
# 45  e45              [1000, 2000]          104       ...              1490.0
# 46  e46              [1000, 2000]           96       ...              1735.0
# 47  e47              [1000, 2000]           57       ...              2037.0
# 48  e48              [1000, 2000]           27       ...              2114.0
# 49  e49              [1000, 2000]           49       ...              2363.0
# 50  e50              [1000, 2000]          113       ...              1920.0
# 51  e51              [1000, 2000]          160       ...              1467.0
# 52  e52              [1000, 2000]          197       ...              1009.0
# 53  e53              [1000, 2000]          397       ...               500.0
#
#     standard deviation of latency (ms) tick metric (T)              type  \
# 0                                   40            1000          Eventual
# 1                                   40            1000          Eventual
# 2                                   40            1000          Eventual
# 3                                   40            1000          Eventual
# 4                                   40            1000          Eventual
# 5                                   40            1000          Eventual
# 6                                   40            1000          Eventual
# 7                                   40            1000          Eventual
# 8                                   40            1000          Eventual
# 9                                   40            1000          Eventual
# 10                                  40            1000          Eventual
# 11                                  40            1000         Federated
# 12                                  40            1000         Federated
# 13                                  40            1000         Federated
# 14                                  40            1000         Federated
# 15                                  40            1000              Raft
# 16                                  40            1000         Federated
# 17                                  40            1000              Raft
# 18                                  40            1000              Raft
# 19                                  40            1000              Raft
# 20                                  40            1000              Raft
# 21                                  40            1000              Raft
# 22                                  40            1000              Raft
# 23                                  40            1000              Raft
# 24                                  40            1000              Raft
# 25                                  40            1000              Raft
# 26                                  40            1000              Raft
# 27                                  40            1000           Stentor
# 28                                  40            1000           Stentor
# 29                                  40            1000         Federated
# 30                                  40            1000           Stentor
# 31                                  40            1000           Stentor
# 32                                  40            1000           Stentor
# 33                                  40            1000           Stentor
# 34                                  40            1000           Stentor
# 35                                  40            1000           Stentor
# 36                                  40            1000           Stentor
# 37                                  40            1000           Stentor
# 38                                  40            1000           Stentor
# 39                                  40            1000  Stentor-Complete
# 40                                  40            1000  Stentor-Complete
# 41                                  40            1000  Stentor-Complete
# 42                                  40            1000  Stentor-Complete
# 43                                  40            1000  Stentor-Complete
# 44                                  40            1000  Stentor-Complete
# 45                                  40            1000  Stentor-Complete
# 46                                  40            1000  Stentor-Complete
# 47                                  40            1000  Stentor-Complete
# 48                                  40            1000  Stentor-Complete
# 49                                  40            1000  Stentor-Complete
# 50                                  40            1000         Federated
# 51                                  40            1000         Federated
# 52                                  40            1000         Federated
# 53                                  40            1000         Federated
#
#     unforked writes  users  visible writes  writes  inconsistent writes  \
# 0               0.0     20            24.0   20118               3143.0
# 1               0.0     20            28.0   20119               2905.0
# 2               0.0     20            26.0   20119               2591.0
# 3               0.0     20            27.0   20118               2466.0
# 4               0.0     20            19.0   20111               2162.0
# 5               0.0     20            18.0   20101               1823.0
# 6               0.0     20            30.0   20069               1244.0
# 7               0.0     20            31.0   20055                  0.0
# 8               0.0     20            19.0   20121               3237.0
# 9               0.0     20            19.0   20123               3477.0
# 10              0.0     20            21.0   20124               3695.0
# 11           1273.0     20         17517.0   20118                145.0
# 12           1070.0     20         17856.0   20119                139.0
# 13           1390.0     20         17265.0   20121                156.0
# 14            803.0     20         18455.0   20119                 88.0
# 15              0.0     20         20055.0   20055                  0.0
# 16           1538.0     20         16970.0   20123                159.0
# 17             94.0     20         19962.0   20069                  0.0
# 18            191.0     20         19899.0   20101                  0.0
# 19            302.0     20         19791.0   20111                  0.0
# 20            399.0     20         19719.0   20118                  0.0
# 21            486.0     20         19633.0   20119                  0.0
# 22            651.0     20         19467.0   20119                  0.0
# 23            753.0     20         19344.0   20118                  0.0
# 24            913.0     20         19190.0   20121                  0.0
# 25            950.0     20         19164.0   20123                  0.0
# 26           1113.0     20         18999.0   20124                  0.0
# 27              0.0     20             0.0   20055                  0.0
# 28              0.0     20             0.0   20069                890.0
# 29           1785.0     20         16441.0   20124                206.0
# 30              0.0     20             0.0   20101               1291.0
# 31              0.0     20             0.0   20111               1610.0
# 32              0.0     20             0.0   20118               1769.0
# 33              0.0     20             0.0   20119               1973.0
# 34              0.0     20             0.0   20119               2215.0
# 35              0.0     20             0.0   20118               2417.0
# 36              0.0     20             0.0   20121               2431.0
# 37              0.0     20             0.0   20123               2542.0
# 38              0.0     20             0.0   20124               2867.0
# 39              0.0     20          8748.0   20101                372.0
# 40              0.0     20          8742.0   20069                219.0
# 41              0.0     20          8789.0   20055                  0.0
# 42              0.0     20          8713.0   20111                538.0
# 43              0.0     20          8625.0   20118                708.0
# 44              0.0     20          8649.0   20119                827.0
# 45              0.0     20          8573.0   20119               1000.0
# 46              0.0     20          8457.0   20118               1171.0
# 47              0.0     20          8373.0   20121               1348.0
# 48              0.0     20          8443.0   20123               1439.0
# 49              0.0     20          8184.0   20124               1577.0
# 50            667.0     20         18724.0   20118                 83.0
# 51            507.0     20         19058.0   20111                 55.0
# 52            331.0     20         19421.0   20101                 34.0
# 53            158.0     20         19738.0   20069                 30.0
#
#               ename
# 0   Pc = 0.7 bailis
# 1   Pc = 0.6 bailis
# 2   Pc = 0.5 bailis
# 3   Pc = 0.4 bailis
# 4   Pc = 0.3 bailis
# 5   Pc = 0.2 bailis
# 6   Pc = 0.1 bailis
# 7   Pc = 0.0 bailis
# 8   Pc = 0.8 bailis
# 9   Pc = 0.9 bailis
# 10  Pc = 1.0 bailis
# 11  Pc = 0.7 bailis
# 12  Pc = 0.6 bailis
# 13  Pc = 0.8 bailis
# 14  Pc = 0.5 bailis
# 15  Pc = 0.0 bailis
# 16  Pc = 0.9 bailis
# 17  Pc = 0.1 bailis
# 18  Pc = 0.2 bailis
# 19  Pc = 0.3 bailis
# 20  Pc = 0.4 bailis
# 21  Pc = 0.5 bailis
# 22  Pc = 0.6 bailis
# 23  Pc = 0.7 bailis
# 24  Pc = 0.8 bailis
# 25  Pc = 0.9 bailis
# 26  Pc = 1.0 bailis
# 27  Pc = 0.0 bailis
# 28  Pc = 0.1 bailis
# 29  Pc = 1.0 bailis
# 30  Pc = 0.2 bailis
# 31  Pc = 0.3 bailis
# 32  Pc = 0.4 bailis
# 33  Pc = 0.5 bailis
# 34  Pc = 0.6 bailis
# 35  Pc = 0.7 bailis
# 36  Pc = 0.8 bailis
# 37  Pc = 0.9 bailis
# 38  Pc = 1.0 bailis
# 39  Pc = 0.2 bailis
# 40  Pc = 0.1 bailis
# 41  Pc = 0.0 bailis
# 42  Pc = 0.3 bailis
# 43  Pc = 0.4 bailis
# 44  Pc = 0.5 bailis
# 45  Pc = 0.6 bailis
# 46  Pc = 0.7 bailis
# 47  Pc = 0.8 bailis
# 48  Pc = 0.9 bailis
# 49  Pc = 1.0 bailis
# 50  Pc = 0.4 bailis
# 51  Pc = 0.3 bailis
# 52  Pc = 0.2 bailis
# 53  Pc = 0.1 bailis
#
# [54 rows x 34 columns]

# %%
# %%memit
#
# def get_message_rows(df):
#     for row in df[['message types', 'tick metric (T)', 'type', 'eid', 'users', 'T parameter model', 'conflict probability']].itertuples():
#         item = row[1]
#         item['experiment'] = "{} Pc = {:0.2f}".format(row[3], row[7])
#         yield item
#
# # Create the data frame
# msgs = pd.DataFrame(sorted(get_message_rows(df), key=lambda item: item['experiment']))
#
# # Create the figure
# fig = plt.figure(figsize=(14,48))
# ax  = fig.add_subplot(111)
# mpl.rcParams.update({'font.size': 22})
#
# # Plot the bar chart
# g = msgs.plot(
#     x='experiment', kind='barh', stacked=True, ax=ax,
#     title="Message Counts by Type", color=sns.color_palette()
# )
#
# # Modify the figure
# ax.set_xlabel("message count")
# ax.yaxis.grid(False)
#
# # Save the figure to disk
# plt.savefig(os.path.join(FIGURES, 'message_counts.png'))
# Out:
# peak memory: 493.07 MiB, increment: 7.43 MiB

# %%
# Forked Writes (two keys: "inconsistent writes" and "forked writes")
g = sns.lmplot(
    x="conflict probability", y="forked writes", hue='type',
    data=df, fit_reg=False, size=7, aspect=1.4, markers=["s","x","o", "p", "d"],
    scatter_kws={'s': 48}
)

# Set the title and the labels 
title_fmt = "Writes Forked for {:,} Accesses".format(df.writes.max())
g.ax.set_title(title_fmt)

# Modify the axis limits  
for ax in g.axes:
    ax[0].set_ylim(-100,)
    ax[0].set_xlim(-0.1,1.1)

# Save the figure to disk 
plt.savefig(os.path.join(FIGURES, 'forked_writes.png'))

# %%
# Forked Writes (two keys: "inconsistent writes" and "forked writes")
g = sns.lmplot(
    x="conflict probability", y="inconsistent writes", hue='type',
    data=df, fit_reg=False, size=7, aspect=1.4, markers=["s","x","o", "p", "d"],
    scatter_kws={'s': 48}
)

# Set the title and the labels 
title_fmt = "Inconsistent Writes for {:,} Accesses".format(df.writes.max())
g.ax.set_title(title_fmt)

# Modify the axis limits  
for ax in g.axes:
    ax[0].set_ylim(-100,)
    ax[0].set_xlim(-0.1,1.1)

# Save the figure to disk 
plt.savefig(os.path.join(FIGURES, 'inconsistent_writes.png'))

# %%
# Dropped Writes
g = sns.lmplot(
    x="conflict probability", y="dropped writes", hue='type', 
    data=df, fit_reg=False, size=7, aspect=1.4, markers=["s","x","o", "p", "d"],
    scatter_kws={'s': 48}
)

# Set the title and the labels 
title_fmt = "Dropped Writes for {:,} Accesses".format(df.writes.max())
g.ax.set_title(title_fmt)

# Modify the axis limits  
for ax in g.axes:
    ax[0].set_ylim(-100,)
    ax[0].set_xlim(-0.1,1.1)

# Save the figure to disk 
plt.savefig(os.path.join(FIGURES, 'dropped_writes.png'))

# %%
# Stale Reads
g = sns.lmplot(
    x="conflict probability", y="stale reads", hue='type', 
    data=df, fit_reg=False, size=7, aspect=1.4, markers=["s","x","o", "p", "d"],
    scatter_kws={'s': 48}
)

# Set the title and the labels 
title_fmt = "Stale Reads for {:,} Accesses".format(df.reads.max())
g.ax.set_title(title_fmt)

# Modify the axis limits  
for ax in g.axes:
    ax[0].set_ylim(-100,)
    ax[0].set_xlim(-0.1,1.1)

# Save the figure to disk 
plt.savefig(os.path.join(FIGURES, 'stale_reads.png'))

# %%
# Visible Writes
g = sns.lmplot(
    x="conflict probability", y="visible writes", hue='type', 
    data=df, fit_reg=False, size=7, aspect=1.4, markers=["s","x","o", "p", "d"],
    scatter_kws={'s': 48}
)

# Set the title and the labels 
title_fmt = "Visible Writes for {:,} Accesses".format(df.writes.max())
g.ax.set_title(title_fmt)

# Modify the axis limits  
for ax in g.axes:
    ax[0].set_ylim(-100,)
    ax[0].set_xlim(-0.1,1.1)

# Save the figure to disk 
plt.savefig(os.path.join(FIGURES, 'visible_writes.png'))

# %%
# Comitted Writes
g = sns.lmplot(
    x="conflict probability", y="committed writes", hue='type', 
    data=df, fit_reg=False, size=7, aspect=1.4, markers=["s","x","o", "p", "d"],
    scatter_kws={'s': 48}
)

# Set the title and the labels 
title_fmt = "Committed Writes for {:,} Accesses".format(df.writes.max())
g.ax.set_title(title_fmt)

# Modify the axis limits  
for ax in g.axes:
    ax[0].set_ylim(-100,)
    ax[0].set_xlim(-0.1,1.1)

# Save the figure to disk 
plt.savefig(os.path.join(FIGURES, 'committed_writes.png'))

# %%
# Number of Messages 
g = sns.lmplot(
    x="conflict probability", y="sent", hue='type', 
    data=df, fit_reg=False, size=7, aspect=1.4, markers=["s","x","o", "p", "d"],
    scatter_kws={'s': 48}
)

# Set the title and the labels 
title_fmt = "Total Sent Messages"
g.ax.set_title(title_fmt)

# Modify the axis limits  
for ax in g.axes:
    ax[0].set_ylim(-100,)
    ax[0].set_xlim(-0.1,1.1)

# Save the figure to disk 
plt.savefig(os.path.join(FIGURES, 'messages_sent.png'))

# %%
# Read cost (ms delay before read)
g = sns.lmplot(
    x="conflict probability", y="mean read latency (ms)", hue='type', 
    data=df, fit_reg=False, size=7, aspect=1.4, markers=["s","x","o", "p", "d"],
    scatter_kws={'s': 48}
)

# Set the title and the labels 
title_fmt = "Read Cost (Latency) for {:,} Accesses".format(df.reads.max())
g.ax.set_title(title_fmt)

# Modify the axis limits  
for ax in g.axes:
    ax[0].set_xlim(-0.1,1.1)

# Save the figure to disk 
plt.savefig(os.path.join(FIGURES, 'read_latency.png'))

# %%
# Write Cost (ms delay before write)
g = sns.lmplot(
    x="conflict probability", y="mean write latency (ms)", hue='type', 
    data=df, fit_reg=False, size=7, aspect=1.4, markers=["s","x","o", "p", "d"],
    scatter_kws={'s': 48}
)

# Set the title and the labels 
title_fmt = "Write Cost (Latency) for {:,} Accesses".format(df.writes.max())
g.ax.set_title(title_fmt)

# Modify the axis limits  
for ax in g.axes:
    ax[0].set_ylim(-100,)
    ax[0].set_xlim(-0.1,1.1)

# Save the figure to disk 
plt.savefig(os.path.join(FIGURES, 'write_latency.png'))

# %%
# Replication Cost (Visibility Latency)
g = sns.lmplot(
    x="conflict probability", y="mean visibility latency (ms)", hue='type', 
    data=df, fit_reg=False, size=7, aspect=1.4, markers=["s","x","o", "p", "d"],
    scatter_kws={'s': 48}
)

# Set the title and the labels 
title_fmt = "Replication Cost (Visibility Latency) for {:,} Accesses".format(df.writes.max())
g.ax.set_title(title_fmt)

# Modify the axis limits  
for ax in g.axes:
    ax[0].set_ylim(-100,)
    ax[0].set_xlim(-0.1,1.1)

# Save the figure to disk 
plt.savefig(os.path.join(FIGURES, 'visibility_latency.png'))

# %%
# Commit Cost (Commit Latency)
g = sns.lmplot(
    x="conflict probability", y="mean commit latency (ms)", hue='type', 
    data=df, fit_reg=False, size=7, aspect=1.4, markers=["s","x","o", "p", "d"],
    scatter_kws={'s': 48}
)

# Set the title and the labels 
title_fmt = "Commit Cost (Latency) for {:,} Accesses".format(df.writes.max())
g.ax.set_title(title_fmt)

# Modify the axis limits  
for ax in g.axes:
    ax[0].set_ylim(-100,)
    ax[0].set_xlim(-0.1,1.1)

# Save the figure to disk 
plt.savefig(os.path.join(FIGURES, 'commit_latency.png'))

# %%
def find_results(etype='federated', Pc=None):
    for result in get_results_data():
        if result.settings['type'] == etype: 
            if (Pc and str(Pc) in result.settings['trace']) or Pc is None:
                name = "{}-Pc{}.png".format(etype, Pc)
                return result, name    
    return None, None 


# Find the desired results 
result, name = find_results('stentor', 0.5)
if result is None: raise ValueError("Could not find results!")

# Extract the Graph Tool graph     
G = extract_graph(result, by_message_type=True)

# Draw the graph 
vlabel  = G.vp['id']
vsize   = G.vp['writes']
vsize   = gt.prop_to_size(vsize, ma=60, mi=20)

# Set the vertex color 
vcolor  = G.new_vertex_property('string') 
vcmap   = ColorMap('flatui', shuffle=False)
for vertex in G.vertices():
    vcolor[vertex] = vcmap(G.vp['consistency'][vertex])

# Set the edge color 
ecolor  = G.new_edge_property('string')
ecmap   = ColorMap('paired', shuffle=False)
for edge in G.edges():
    ecolor[edge] = ecmap(G.ep['label'][edge])

elabel  = G.ep['label']
esize   = G.ep['norm']
esize   = gt.prop_to_size(esize, mi=2, ma=5)

# Create the layout with the edge weights. 
# pos = gt.arf_layout(G, weight=G.ep['weight'])
pos = gt.sfdp_layout(G, eweight=G.ep['weight'], vweight=vsize)
# pos = gt.fruchterman_reingold_layout(G, weight=G.ep['weight'])

gt.graph_draw(
    G, pos=pos, output_size=(1200,1200), output=os.path.join(FIGURES, name),
    vertex_text=vlabel, vertex_size=vsize, vertex_font_weight=1, 
    vertex_pen_width=1.3, vertex_fill_color=vcolor,
    edge_pen_width=esize, edge_color=ecolor, edge_text=elabel
)
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x1200d89d0, at 0x10aefd110>
